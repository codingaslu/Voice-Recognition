# %%
# !pip install speaker-verification-toolkit
# Out:
# Collecting speaker-verification-toolkit
#   Downloading speaker_verification_toolkit-0.0.2-py3-none-any.whl (5.5 kB)
# Collecting python-speech-features==0.6
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
# Collecting librosa==0.7.0
#   Downloading librosa-0.7.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 10.2 MB/s
# Collecting fastdtw==0.3.2
#   Downloading fastdtw-0.3.2.tar.gz (118 kB)
#      |████████████████████████████████| 118 kB 39.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fastdtw==0.3.2->speaker-verification-toolkit) (1.19.5)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (2.1.9)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (1.0.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (4.4.2)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (1.15.0)
# Requirement already satisfied: resampy>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (0.2.2)
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (0.51.2)
# Requirement already satisfied: soundfile>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.7.0->speaker-verification-toolkit) (0.10.3.post1)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.38.0->librosa==0.7.0->speaker-verification-toolkit) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.38.0->librosa==0.7.0->speaker-verification-toolkit) (57.4.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.9.0->librosa==0.7.0->speaker-verification-toolkit) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.9.0->librosa==0.7.0->speaker-verification-toolkit) (2.20)
# Building wheels for collected packages: fastdtw, librosa, python-speech-features
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.2-cp37-cp37m-linux_x86_64.whl size=363602 sha256=f3eb5b3091870899311000c2ab0c34013494b85fdfb03acec3b1067ff631408d
#   Stored in directory: /root/.cache/pip/wheels/ff/ca/61/151bee1bda7f12114923484374a437365767c1e57e811fb76b
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.7.0-py3-none-any.whl size=1598360 sha256=02dca0a32b5b541e13b8149319b36cb70c5c837c543f3908115d2ec3aed3a315
#   Stored in directory: /root/.cache/pip/wheels/f5/0d/b1/71a4e1863d7577a218f771df59c7582996580fa07ac79d68fd
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=ff202278853d4a5085b56304ba27308bad672eeeb6b8a20418f4c8cced11ec02
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built fastdtw librosa python-speech-features
# Installing collected packages: python-speech-features, librosa, fastdtw, speaker-verification-toolkit
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
#   Attempting uninstall: fastdtw
#     Found existing installation: fastdtw 0.3.4
#     Uninstalling fastdtw-0.3.4:
#       Successfully uninstalled fastdtw-0.3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.5 requires librosa>=0.7.2, but you have librosa 0.7.0 which is incompatible.
# Successfully installed fastdtw-0.3.2 librosa-0.7.0 python-speech-features-0.6 speaker-verification-toolkit-0.0.2

# %%
# !pip install numba==0.48
# Out:
# Collecting numba==0.48
#   Downloading numba-0.48.0-1-cp37-cp37m-manylinux2014_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 7.9 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from numba==0.48) (1.19.5)
# Collecting llvmlite<0.32.0,>=0.31.0dev0
#   Downloading llvmlite-0.31.0-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      |████████████████████████████████| 20.2 MB 1.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.48) (57.4.0)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.5 requires librosa>=0.7.2, but you have librosa 0.7.0 which is incompatible.
# Successfully installed llvmlite-0.31.0 numba-0.48.0

# %%
import speaker_verification_toolkit.tools as svt

# %%
import librosa

# %%
librosa.load('/Prakriti.wav')
# Out:
# (array([-6.6978714e-07,  8.1520119e-07, -9.6907604e-07, ...,
#          3.8325019e-02,  3.4522779e-02,  3.6402646e-02], dtype=float32), 22050)

# %%
data1, sr = librosa.load('/Prakriti_2.wav', sr=16000, mono=True)
data2, sr = librosa.load('/Prakriti.wav', sr=16000, mono=True)

data1 = svt.rms_silence_filter(data1)
data2 = svt.rms_silence_filter(data2)

data1 = svt.extract_mfcc(data1)
data2 = svt.extract_mfcc(data2)

print(
    'The difference between voice1 and voice2 is',
    svt.compute_distance(data1,data2)
)
# Out:
# The difference between voice1 and voice2 is 136760.3550290822

# %%
svt.compute_distance(data1, data2)
# Out:
# 136760.3550290822

# %%
data3, sr = librosa.load('/example.wav', sr=16000, mono=True)
data3 = svt.rms_silence_filter(data3)
data3 = svt.extract_mfcc(data3)

# %%
svt.compute_distance(data3, data2)
# Out:
# 1013011.269559927

# %%
svt.find_nearest_voice_data([ data3, data1], data2)
# Out:
# 1
